# %%
import json
import intervaltree
import csv
import pandas as pd
import numpy as np

# %%
def read_CD(path):
    t = pd.read_csv(path)
    annotations = []
    primary_rtime = None
    primary_mz = None
    for name, mz, rtime, sub_name in zip(t["Name"], t["m/z"], t["RT [min]"], t["Annot. Source: mzVault Search"]):
        if name != "No results" and name != "Tags":
            if isinstance(name, str):
                primary_rtime = rtime
                primary_mz = mz
                annotations.append({"Name": name, "m/z": mz, "RT [min]": rtime})
            elif isinstance(sub_name, str) and sub_name != "No results":
                annotations.append({"Name": sub_name, "m/z": primary_mz, "RT [min]": primary_rtime})
    return annotations

# %%
def read_pcpfm(path):
    return json.load(open(path))

# %%
def map_CD_annots(cd_annots, pcpfm_annots, mz_ppm_tol=10, rt_err=30):
    mz_tree, rt_tree = intervaltree.IntervalTree(), intervaltree.IntervalTree()
    khipu_to_features, features_to_khipu = {}, {}
    for kp_id, kp in pcpfm_annots.items():
        for peak in kp["MS1_pseudo_Spectra"]:
            id = peak['id_number']
            features_to_khipu[id] = kp_id
            if kp_id in khipu_to_features:
                khipu_to_features[kp_id].append(id)
            else:
                khipu_to_features[kp_id] = [id]
            mz, rtime = peak['mz'], peak['rtime']
            mz_err = mz / 1e6 * mz_ppm_tol
            mz_tree.addi(mz - mz_err, mz + mz_err, id)
            rt_tree.addi(rtime - rt_err, rtime + rt_err, id)            
    
    for cd_annot in cd_annots:
        cd_annot['mapped_to'] = set()
        if cd_annot['Name']:
            mz = float(cd_annot['m/z'])
            rt = float(cd_annot['RT [min]']) * 60
            mz_matches = {x.data for x in mz_tree.at(mz)}
            rt_matches = {x.data for x in rt_tree.at(rt)}
            for match in mz_matches.intersection(rt_matches):
                for khipu_feature in khipu_to_features[features_to_khipu[match]]:
                    cd_annot['mapped_to'].add(khipu_feature)
    return cd_annots

# %%
def eval_overlap(cd_path, pcpfm_path):
    CD_annots = read_CD(cd_path)
    PCPFM_annots = read_pcpfm(pcpfm_path)
    CD_annots = map_CD_annots(CD_annots, PCPFM_annots, mz_ppm_tol=10)

    all_CD_annot_cpds = set()
    all_PCPFM_annot_cpds = set()

    for cd_annot in CD_annots:
        for feature in cd_annot["mapped_to"]:
            all_CD_annot_cpds.add(cd_annot["Name"] + "_" + feature)

    for kp_id, kp in PCPFM_annots.items():
        if "MS2_Spectra" in kp:
            for MS2 in kp["MS2_Spectra"]:
                all_annotations = [(annotation, annotation["msms_score"]) for annotation in MS2["annotations"] if annotation["annotation_level"] == "Level_2"]
                all_annotations = sorted(all_annotations, key=lambda x: -x[1])
                all_annotations = [x[0] for x in all_annotations]
                for annotation in all_annotations:
                    for peak in kp["MS1_pseudo_Spectra"]:
                        all_PCPFM_annot_cpds.add(annotation['reference_id'] + "_" + peak['id_number'])

    print("CD All:", len(all_CD_annot_cpds), "PCPFM All:", len(all_PCPFM_annot_cpds))
    CD_in_PCPFM = all_CD_annot_cpds.intersection(all_PCPFM_annot_cpds)
    print("Shared Annotations: ", len(CD_in_PCPFM))
    print("CD Only:", len(all_CD_annot_cpds) - len(CD_in_PCPFM))
    print("PCPFM Only:", len(all_PCPFM_annot_cpds) - len(CD_in_PCPFM))
    print(CD_in_PCPFM)

# %%
# RP NEG 
eval_overlap("./CD_MoNA_RP_neg.csv", "/Users/mitchjo/Analyses/HZV029_plasma_RP_neg/output/RP_neg_with_auth_stds_MS2_empCpds.json") # 30 sec
# copy these numbers to csv for venn diagram
# Out:
# CD All: 2515 PCPFM All: 3070
# Shared Annotations:  1016
# CD Only: 1499
# PCPFM Only: 2054
# {'D-(-)-Quinic acid_F3238_227.0324@28.91', '3-METHYLSALICYLIC ACID_F8909_151.0401@91.93', '3-HYDROXYBUTYRIC ACID_F2775_104.0434@57.01', 'GLUTAMINE_F8031_145.0619@26.59', 'trans-Aconitic acid_F1392_173.0092@36.83', '2-HYDROXYBUTYRIC ACID_F2725_103.0405@73.72', 'L-Tryptophan_F8490_203.0826@80.04', 'Succinic acid; LC-tDDA; CE40_F4001_118.0227@33.15', '3-Hydroxyphenylalanine_F3078_180.0667@54.36', 'Tauroallocholic acid_F24438_514.287@106.74', 'Succinic acid; LC-tDDA; CE10_F3882_117.0193@33.54', 'LPE 18:1_F24032_479.2994@179.26', 'Acesulfame_F10474_161.9868@79.21', 'ALA-GLY_F3406_181.0376@26.21', 'Salicyluric acid; LC-tDDA; CE10_F5589_236.0762@83.36', 'ARABINOSE_F8940_151.0521@28.91', '5-OXO-L-PROLINE_F5287_129.0387@51.3', 'D-Pantothenic acid_F1189_218.1034@76.69', 'cis-Aconitic Acid_F9776_209.9893@28.91', 'RIBOSE_F4421_185.0226@28.13', '(1S,3R,4S,5R)-1,3,4,5-tetrahydroxycyclohexane-1-carboxylic acid_F5918_191.0562@28.91', '12-Hydroxyoctadecanoic acid_F13260_300.262@199.89', 'ALA-GLY_F3417_181.0386@26.97', '4-Methoxyphenol sulfate_F8344_203.002@106.74', 'Glu-Gln_F5750_274.1046@28.91', 'D-(-)-Quinic acid_F3960_230.0165@31.99', 'Bilirubin; LC-tDDA; CE40_F28017_605.2385@209.07', 'Carboxyibuprofen_F1852_257.0792@102.9', 'TRYPTOPHAN_F8594_204.0859@80.04', 'Carboxyibuprofen_F5515_235.0985@101.74', 'Succinic acid; LC-tDDA; CE40_F3882_117.0193@33.54', 'XYLOSE_F8940_151.0521@28.91', 'RIBOSE_F8940_151.0521@28.91', 'INDOLELACTIC ACID_F7249_243.0872@92.71', '3-Hydroxybenzoic acid sulfate_F841_216.981@85.85', 'Inosine_F4490_269.0792@73.29', '(1S,3R,4S,5R)-1,3,4,5-tetrahydroxycyclohexane-1-carboxylic acid_F5921_191.0572@28.91', '10-HYDROXYDECANOIC ACID_F3526_228.1613@117.44', 'Bilirubin_F28102_606.2443@209.07', 'GLYCOCHENODEOXYCHOLATE_F23952_450.3152@107.51', 'SCDCA - Sulfochenodeoxycholic acid_F22403_472.2452@125.43', '1-(9Z,12Z-Octadecadienoyl-2-hydroxy-sn-glycero-3-phosphocholine_F29411_567.339@165.15', 'Bilirubin; LC-tDDA; CE20_F28226_607.2447@209.07', 'L-Citrulline_F1685_174.0885@27.35', 'Glycochenodeoxycholic acid; LC-tDDA; CE40_F23950_450.3127@118.2', 'Uric acid; LC-tDDA; CE20_F519_168.0245@31.99', 'Pyroglutamic acid_F5063_128.0353@32.37', 'Succinic acid; LC-tDDA; CE40_F3902_117.0205@33.15', '5-OXO-L-PROLINE_F5063_128.0353@32.37', 'Pantothenic acid; LC-tDDA; CE10_F1094_254.0801@75.83', 'Succinic acid; LC-tDDA; CE40_F9920_158.0461@31.99', 'Glutamine_F3417_181.0386@26.97', 'LPC 16:0_F26226_540.3307@176.98', 'Terephthalic acid_F11200_165.0202@204.85', 'Methylmalonic acid; LC-tDDA; CE20_F3882_117.0193@33.54', 'TAUROURSODEOXYCHOLIC ACID_F22175_501.2975@140.31', 'Phthalic acid_F4793_187.0026@199.89', '1,4-Cyclohexanedicarboxylic acid_F915_171.0663@95.08', 'QUINATE_F6104_192.0597@28.91', 'GLYCOCHENODEOXYCHOLIC ACID_F23949_450.3127@108.66', '2,5-DIHYDROXYBENZOIC ACID_F1967_175.0011@100.16', 'TRANS-ACONITATE_F9415_208.9874@29.69', 'TAUROCHENODEOXYCHOLIC ACID_F21556_498.2893@139.93', '2-Methoxyphenol sulfate_F8729_205.0092@107.13', '2-HYDROXYOCTANOIC ACID_F8121_201.1336@104.43', 'SUCCINATE_F3882_117.0193@33.54', 'LPE 18:2_F23537_477.2813@160.57', '10-HYDROXYDECANOIC ACID_F5254_188.1373@122.39', 'Aconitic acid_F1397_173.01@30.07', 'Glycochenodeoxycholic acid; LC-tDDA; CE30_F23953_450.3152@117.44', '3-Phenyllactic acid_F21_165.0558@94.29', 'GLUTAMINE_F3406_181.0376@26.21', '4-HYDROXYPHENYL ACETIC ACID_F6119_192.0673@92.71', 'Xylose_F8736_149.0456@29.31', 'Acetaminophen glucuronide_F17099_362.0646@73.72', 'trans-Aconitic acid_F9409_208.9863@29.69', 'Succinic acid; LC-tDDA; CE10_F3902_117.0205@33.15', '2-Methoxyphenol sulfate_F8344_203.002@106.74', 'GLYCOCHOLATE_F21113_466.3078@107.13', 'Uridine_F7201_280.0421@31.99', 'Bilirubin; LC-tDDA; CE40_F25936_585.2628@209.07', 'Dodecanedioic acid_F3827_229.1443@110.19', 'XYLOSE_F8736_149.0456@29.31', 'Tauroursocholic acid_F24434_514.2843@105.59', 'cis-Aconitic acid_F9415_208.9874@29.69', 'Dehydroepiandrosterone sulfate; LC-tDDA; CE20_F18494_367.1579@135.71', 'ACONITIC ACID_F1607_174.0125@31.99', 'P-CRESOL SULFA ...

# %%
# HILIC POS
eval_overlap("./CD_MoNA_HILIC_pos.csv", "/Users/mitchjo/Analyses/HZV029_plasma_HILIC_pos/output/HILIC_pos_with_auth_stds_MS2_empCpds.json")
# copy these numbers for venn diagram
# Out:
# CD All: 4000 PCPFM All: 5437
# Shared Annotations:  1800
# CD Only: 2200
# PCPFM Only: 3637
# {'Oleoyl-carnitine; AIF; CE30; MS2Dec_F25640_427.3616@79.61', 'INOSINE_F14569_291.0703@103.6', 'Paracetamol_F3618_153.074@21.16', 'Trazodone_F20207_372.1589@17.0', '4-Pyridoxate_F9418_206.0425@23.45', 'ADMA_F8359_203.1504@218.37', 'N_N-DIMETHYLARGININE_F8359_203.1504@218.37', 'Piperidine_F700_86.0968@98.14', 'D-TRYPTOPHAN_F3295_227.08@112.91', 'Allopurinol_F12277_138.0488@103.6', '7-Methylguanine; AIF; CE10; CorrDec_F8672_167.0758@76.56', 'Palmitoyl-carnitine; LC-tDDA; CE10_F28867_403.3534@81.14', 'Piperine_F13915_289.1551@17.0', '3-METHYLHISTIDINE_F9728_170.0925@207.21', '3-AMINO-5-HYDROXYBENZOIC ACID_F4479_156.057@24.94', '4-Hydroxypyridine; AIF; CE10; CorrDec_F1721_96.0448@31.5', 'Pyroglutamic acid_F3535_153.0357@173.12', '5-HYDROXYINDOLE_F11584_135.0634@18.5', '2-Oxindole; LC-tDDA; CE20_F10174_172.0157@20.02', 'Tryptophan_F9859_207.1039@113.66', '4-Aminophenol_F5136_111.0635@17.38', 'cis-1,2,3,6-Tetrahydrophthalimide_F4247_155.0816@23.45', 'Paracetamol_F3368_152.0707@18.5', 'MALTOSE_F18297_366.1094@161.51', 'Crotonoside_F14331_322.0563@122.37', '4-Hydroxypyridine; AIF; CE10; CorrDec_F1905_97.0477@17.75', 'Paracetamol_F5814_196.1082@23.82', 'ALLOTHREONINE_F7829_120.0656@164.17', '5,6-DIHYDROURACIL_F9593_170.0327@163.42', 'Guanosine_F19569_306.0814@122.75', '1-Methylnicotinamide chloride_F12078_137.071@130.85', 'Proline-hydroxyproline_F5011_232.1293@196.09', '3-HYDROXYANTHRANILIC ACID_F6180_197.0842@25.32', 'Lysine_F1941_147.1129@227.78', 'BETA-ALANINE_F1147_90.0549@161.12', 'trans-2-Octenoyl-carnitine; AIF; CE30; MS2Dec_F13306_287.2049@93.53', '1-METHYLNICOTINAMIDE_F12603_139.0776@130.46', 'HISTIDINE_F4524_156.0769@225.91', 'Decanoyl-L-Carnitine_F23089_317.2519@86.06', '3-METHYLHISTIDINE (ALLCAPS7)_F10327_172.099@206.83', 'Decanoyl-L-Carnitine_F13472_318.2549@86.06', 'PC(16:0/0:0)_F24657_499.3486@90.92', 'Piperine_F12962_286.1441@15.09', 'Atenolol_F16638_267.1716@80.75', 'Creatine - CASMI2016 Category 1 - Challenge 10_F11794_136.0482@75.06', "2'-O-Methyluridine_F14127_260.0958@169.25", 'LINOLENIC ACID_F21239_280.2355@23.45', '4-Pyridoxic acid_F2048_185.0639@23.82', '2-Acetamidophenol_F10965_174.0532@21.55', '1-Acetylimidazole_F4290_155.0911@222.16', 'Glutamine_F2399_149.083@173.51', 'Phenylacetylglutamine; AIF; CE30; CorrDec_F16544_267.1252@105.88', 'Omeprazole; AIF; CE10; MS2Dec_F17998_365.0998@17.38', 'PARAXANTHINE_F915_182.0753@22.32', 'HYPOXANTHINE_F12502_139.0527@76.18', 'INOSINE_F18124_271.0938@104.0', 'Losartan_F24627_423.1699@23.08', '2-HYDROXYPYRIDINE_F1720_96.0448@17.75', 'N-ACETYL-ALANINE_F10678_132.0656@159.98', 'Paracetamol_F10965_174.0532@21.55', 'Acetaminophen_F5814_196.1082@23.82', 'isomaltulose_F20716_343.1236@176.63', 'LysoPC(0:0/18:0)_F35699_563.3304@88.32', 'Hypoxanthine_F12013_137.0458@76.18', 'L-GLUTAMINE_F9252_169.0585@173.51', '1-METHYLNICOTINAMIDE_F12078_137.071@130.85', 'Acetaminophen / paracetamol_F3618_153.074@21.16', '2-Hydroxypyridine; AIF; CE10; CorrDec_F1717_96.0444@31.89', 'β-Gentiobiose_F18585_367.1119@176.24', 'gamma-Linolenic acid_F20975_279.2321@23.45', 'Lyso-PC 18:0_F33084_547.3593@89.43', '2-Oxo-5-(3,3-dimethylguanidine-1-yl)pentanoic acid_F7905_202.1188@128.14', 'Atenolol_F17508_269.1777@81.52', 'L-Norleucine_F11447_134.1085@121.63', 'cis-1,2,3,6-Tetrahydrophthalimide_F3618_153.074@21.16', 'CHOLINE_F1594_146.1376@120.5', 'Trehalose_F18006_365.1059@175.86', 'Palmitoyl-L-Carnitine_F28320_401.3458@80.75', '3-Hydroxyanthranilic acid_F4138_155.0536@25.71', '1-Methylhistidine; AIF; 10eV; MS2Dec_F9728_170.0925@207.21', 'Palmitoyl-carnitine; AIF; CE10; CorrDec_F28609_402.3489@80.75', 'TRYPTOPHAN_F3295_227.08@112.91', 'Choline chloride_F4011_104.107@118.98', 'Glutamylphenylalanine (isomer of 1503)_F15930_295.1291@155.36', 'DL-Pipecolinic acid_F9920_130.0873@227.78', '2-PHENYLACETAMIDE_F1632_95.0495@138.18', '2-Oxindole; LC-tDDA; CE20_F11886_136.0666@18.87', 'CREATINE_F11384_134.0833@163.42', '4-PYRIDOXIC ACID_F9738_207.0457@23.45', '3-Aminoacetophenon_F12111_137.0795@138.18', 'BETA-ALANINE_F11 ...

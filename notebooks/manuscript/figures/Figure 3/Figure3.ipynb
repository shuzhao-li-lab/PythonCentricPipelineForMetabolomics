# %%
import json
import intervaltree
import csv
import pandas as pd
import numpy as np

# %%
def read_CD(path):
    t = pd.read_csv(path)
    annotations = []
    primary_rtime = None
    primary_mz = None
    for name, mz, rtime, sub_name in zip(t["Name"], t["m/z"], t["RT [min]"], t["Annot. Source: mzVault Search"]):
        if name != "No results" and name != "Tags":
            if isinstance(name, str):
                primary_rtime = rtime
                primary_mz = mz
                annotations.append({"Name": name, "m/z": mz, "RT [min]": rtime})
            elif isinstance(sub_name, str) and sub_name != "No results":
                annotations.append({"Name": sub_name, "m/z": primary_mz, "RT [min]": primary_rtime})
    return annotations

# %%
def read_pcpfm(path):
    return json.load(open(path))

# %%
def map_CD_annots(cd_annots, pcpfm_annots, mz_ppm_tol=10, rt_err=30):
    mz_tree, rt_tree = intervaltree.IntervalTree(), intervaltree.IntervalTree()
    khipu_to_features, features_to_khipu = {}, {}
    for kp_id, kp in pcpfm_annots.items():
        for peak in kp["MS1_pseudo_Spectra"]:
            id = peak['id_number']
            features_to_khipu[id] = kp_id
            if kp_id in khipu_to_features:
                khipu_to_features[kp_id].append(id)
            else:
                khipu_to_features[kp_id] = [id]
            mz, rtime = peak['mz'], peak['rtime']
            mz_err = mz / 1e6 * mz_ppm_tol
            mz_tree.addi(mz - mz_err, mz + mz_err, id)
            rt_tree.addi(rtime - rt_err, rtime + rt_err, id)            
    
    for cd_annot in cd_annots:
        cd_annot['mapped_to'] = set()
        if cd_annot['Name']:
            mz = float(cd_annot['m/z'])
            rt = float(cd_annot['RT [min]']) * 60
            mz_matches = {x.data for x in mz_tree.at(mz)}
            rt_matches = {x.data for x in rt_tree.at(rt)}
            for match in mz_matches.intersection(rt_matches):
                for khipu_feature in khipu_to_features[features_to_khipu[match]]:
                    cd_annot['mapped_to'].add(khipu_feature)
    return cd_annots

# %%
def eval_overlap(cd_path, pcpfm_path):
    CD_annots = read_CD(cd_path)
    PCPFM_annots = read_pcpfm(pcpfm_path)
    CD_annots = map_CD_annots(CD_annots, PCPFM_annots, mz_ppm_tol=10)

    all_CD_annot_cpds = set()
    all_PCPFM_annot_cpds = set()

    for cd_annot in CD_annots:
        for feature in cd_annot["mapped_to"]:
            all_CD_annot_cpds.add(cd_annot["Name"] + "_" + feature)

    for kp_id, kp in PCPFM_annots.items():
        if "MS2_Spectra" in kp:
            for MS2 in kp["MS2_Spectra"]:
                all_annotations = [(annotation, annotation["msms_score"]) for annotation in MS2["annotations"]]
                all_annotations = sorted(all_annotations, key=lambda x: -x[1])
                all_annotations = [x[0] for x in all_annotations[:10]]
                for annotation in all_annotations:
                    for peak in kp["MS1_pseudo_Spectra"]:
                        all_PCPFM_annot_cpds.add(annotation['reference_id'] + "_" + peak['id_number'])

    print(len(all_CD_annot_cpds), len(all_PCPFM_annot_cpds))
    CD_in_PCPFM = all_CD_annot_cpds.intersection(all_PCPFM_annot_cpds)
    print("Shared Annotations: ", len(CD_in_PCPFM))
    print(CD_in_PCPFM)

# %%
# RP NEG 
eval_overlap("./CD_MoNA_RP_neg.csv", "./HZV029_RP_neg_MoNA_annotations.json") # 30 sec
# Out:
# 2501 1540
# Shared Annotations:  710
# {'Glutamic acid_F8787', '1,3-Benzenedicarboxylic acid_F11193', 'Glycochenodeoxycholic acid; LC-tDDA; CE30_F22415', 'GLYCOCHENODEOXYCHOLIC ACID_F19836', 'Glycochenodeoxycholic acid; LC-tDDA; CE40_F24121', 'LPE 18:1_F23582', '3-phenyllactic acid_F8880', 'Glycochenodeoxycholic acid; LC-tDDA; CE30_F23858', 'DL-Glyceric acid_F2877', '(2-{[2-hexadecanamido-3-hydroxyoctadec-4-en-1-yl phosphono]oxy}ethyl)trimethylazanium_F32078', 'Glycochenodeoxycholic acid; LC-tDDA; CE30_F19836', 'Succinic acid_F3870', 'Quinic acid_F3742', 'Bilirubin_F28120', 'Xylose_F8849', 'Quinic acid_F5865', 'Xylose_F4415', 'Terephthalic acid_F11193', 'Aconitic Acid_F1382', '5-OXO-D-PROLINE_F5271', 'Acetaminophen-glucuronide; LC-tDDA; CE40_F16952', '(R)-2-hydroxystearic acid_F12929', 'Methylmalonic acid; LC-tDDA; CE20_F3974', 'LACTIC ACID_F661', '5-OXO-D-PROLINE_F5277', '(R)-2-hydroxystearic acid_F16936', 'TAUROCHOLIC ACID_F24523', 'Acetaminophen glucuronide_F13957', 'TRANS-ACONITATE_F1611', '(1S,3R,4S,5R)-1,3,4,5-tetrahydroxycyclohexane-1-carboxylic acid_F3742', 'Dehydroepiandrosterone sulfate; LC-tDDA; CE30_F18712', 'ACESULFAME K_F10588', 'Acesulfame_F10462', '5-OXO-D-PROLINE_F5053', 'Tryptophan_F8533', 'ACONITIC ACID_F1625', 'Trophicardyl_F14087', 'Acetaminophen-glucuronide; LC-tDDA; CE40_F14404', 'P-CRESOL SULFATE_F5453', '3-Hydroxybenzoic acid sulfate_F1101', '4-Methoxyphenol sulfate_F8278', 'Acetaminophen-glucuronide; LC-tDDA; CE40_F13947', '(R)-2-hydroxystearic acid_F12928', '3-(4-HYDROXYPHENYL)PROPIONIC ACID_F8880', '12-Hydroxyoctadecanoic acid_F13205', '(R)-2-hydroxystearic acid_F17848', 'INDOLELACTIC ACID_F7315', 'GLYCOCHENODEOXYCHOLIC ACID_F24396', 'LACTIC ACID_F1234', 'METHYLMALONATE_F3864', 'CMPF_F6802', 'Trophicardyl_F4296', 'TRANS-ACONITATE_F1389', '5-OXO-L-PROLINE_F5277', 'Glycochenodeoxycholic acid; LC-tDDA; CE20_F19836', '[(4E)-7-acetyloxy-6-hydroxy-2-methyl-10-oxo-2,3,6,7,8,9-hexahydrooxecin-3-yl] (E)-but-2-enoate_F13067', 'GLYCOCHENODEOXYCHOLIC ACID_F23855', 'SCDCA - Sulfochenodeoxycholic acid_F22130', 'Aconitic Acid_F1611', '(2-{[2-hexadecanamido-3-hydroxyoctadec-4-en-1-yl phosphono]oxy}ethyl)trimethylazanium_F32079', 'Citric acid (Not validated, isomer of 227)_F5857', 'TAUROCHOLIC ACID_F24717', 'Tauroursocholic acid_F24716', '2-HYDROXYOCTANOIC ACID_F10230', 'GLUTAMIC ACID_F8431', 'cis-Aconitic Acid_F1389', 'LPC 18:2_F28924', 'Acetaminophen-glucuronide; LC-tDDA; CE20_F17290', 'LPE 16:0_F24574', '12-Hydroxyoctadecanoic acid_F17848', '10-Hydroxydecanoic acid_F3562', 'Glycocholic Acid_F20419', 'TAUROCHENODEOXYCHOLIC ACID_F22244', 'Quinic acid_F6060', 'Glycochenodeoxycholic acid; LC-tDDA; CE20_F19587', 'Glu-Gln_F5750', 'LACTIC ACID_F642', 'ISOCITRIC ACID_F5857', 'Tauroursocholic acid_F24881', 'D-(-)-Quinic acid_F5877', 'D-(-)-quinic acid_F3281', 'ARABINOSE_F4394', 'Glutamine_F3371', 'INDOLELACTIC ACID_F7903', 'Bilirubin_F26181', 'LPC 18:3_F28723', 'Acetaminophen-glucuronide; LC-tDDA; CE30_F14404', 'O-HYDROXYHIPPURIC ACID_F5556', 'Glycocholic Acid_F20942', 'Glycochenodeoxycholic acid; LC-tDDA; CE40_F19836', 'Bilirubin_F28311', 'ACONITIC ACID_F1382', '[(4E)-7-acetyloxy-6-hydroxy-2-methyl-10-oxo-2,3,6,7,8,9-hexahydrooxecin-3-yl] (E)-but-2-enoate_F16981', 'cis-Aconitic acid_F9701', 'Glycochenodeoxycholic acid; LC-tDDA; CE40_F24114', '2-HYDROXYOCTANOIC ACID_F7850', 'cis-Aconitic acid_F1612', 'ALA-GLY_F3380', 'Bilirubin_F29614', 'Xylose_F8960', 'ISOCITRIC ACID_F6057', 'Glycochenodeoxycholic acid; LC-tDDA; CE30_F23854', 'Aconitic Acid_F9315', '2,6-DIHYDROXYBENZOIC ACID_F9208', 'PANTOTHENIC ACID_F1475', 'Carboxyibuprofen_F5851', 'TAUROCHENODEOXYCHOLIC ACID_F22043', 'TAUROCHENODEOXYCHOLIC ACID_F21865', 'GLYCOCHOLATE_F20942', 'GLYCOCHENODEOXYCHOLIC ACID_F19385', '5-Methoxysalicylic acid sulfate_F8323', 'QUINIC ACID_F3742', 'cis-Aconitic acid_F1383', '2-HYDROXYOCTANOIC ACID_F10123', 'Dehydroepiandrosterone sulfate; LC-tDDA; CE30_F18356', 'Glycochenodeoxycholic acid; LC-tDDA; CE30_F24397', 'Tauroallocholic acid_F24716', 'D-Pantothenic Acid_F1205', '3-phenyll ...

# %%
# HILIC POS
eval_overlap("./CD_MoNA_HILIC_pos.csv", "./HZV029_HILIC_pos_MoNA_annotations.json")
# Out:
# 3998 3490
# Shared Annotations:  1455
# {'Linoleyl-carnitine; AIF; CE30; CorrDec_F24748', 'Palmitoyl-carnitine; LC-tDDA; CE20_F28290', 'PROLINE_F6805', 'Omeprazole; AIF; CE10; CorrDec_F18004', 'cis-1,2,3,6-Tetrahydrophthalimide_F3584', 'L-Tryptophan_F9538', 'Pyroglutamic acid_F10702', '2-Aminophenol_F3360', 'Oleoyl-L-Carnitine_F25461', '4-Hydroxymandelonitrile_F2943', '2-HYDROXYPYRIDINE_F1699', 'N-Methylproline_F9946', 'Phenylacetylglutamine; AIF; CE30; CorrDec_F13541', 'Oleoyl-carnitine; LC-tDDA; CE30_F26294', 'THEOPHYLLINE_F607', 'PHENYLALANINE_F3793', '3-Methylhistidine (v7)_F10239', 'Palmitoyl-L-Carnitine_F24739', 'N-Methylproline_F9964', 'BILIVERDIN_F38987', 'Biliverdin_F38987', 'CREATININE_F3492', 'N_N-DIMETHYLARGININE_F8397', 'Glycoursodeoxycholic acid_F23390', 'GUANIDINEACETIC ACID_F7684', 'Phenylacetylglutamine; AIF; CE30; CorrDec_F15743', 'lenticin_F10309', '3-Pyridinol_F1691', 'N6-Methyl-lysine; AIF; CE30; MS2Dec_F6231', '3-HYDROXYANTHRANILIC ACID_F4443', '3-Methylhistidine_F9867', 'Erucamide; AIF; CE10; CorrDec_F19308', 'N-Methylproline_F10803', 'Proline-hydroxyproline_F3858', 'Isobutyryl-carnitine; AIF; CE10; MS2Dec_F5673', 'N6-Methyl-lysine; AIF; CE30; MS2Dec_F7496', 'Valeryl-carnitine; AIF; CE10; MS2Dec_F9375', 'Lyso-PC 18:0_F35630', '3-Methylhistidine (v10)_F10239', 'GLUTAMIC ACID_F2330', 'phenylacetylglutamine_F16471', '3-Methylpyrazole_F136', '1,5-Naphthalenediamine_F5446', 'PIPECOLIC ACID_F3329', 'PROLINE_F7186', 'Isobutyryl-carnitine; AIF; CE10; MS2Dec_F6031', 'Paracetamol_F3583', 'N-Methylproline_F10354', '1-Methylnicotinamide_F12146', 'Oleoyl-carnitine; LC-tDDA; CE30_F25993', 'PC(16:0/18:1(9Z))_F37594', 'N-Acetylputrescine; AIF; CE10; CorrDec_F10895', 'ADENOSINE_F17283', '1-Stearoyl-sn-glycero-3-phosphocholine_F36577', 'Glycochenodeoxycholate_F31633', '4-Hydroxybenzaldehyde_F8287', 'Guanosine_F14312', 'Acetaminophen_F3584', 'Acetaminophen / paracetamol_F4841', 'Phenylacetylglutamine_F18644', '4-Pyridoxic acid; AIF; CE10; MS2Dec_F9795', '1-heptadecanoyl-2-hydroxy-sn-glycero-3-phosphocholine_F27030', 'PIPECOLIC ACID_F10352', 'Palmitoyl-carnitine; LC-tDDA; CE30_F24739', 'L-GLUTAMINE_F9178', 'Glycochenodeoxycholate_F30942', '"Mirtazapine (Remeron, Avanza)"_F16121', '4-Pyridoxic acid; AIF; CE10; CorrDec_F2085', 'Atenolol_F16956', 'lenticin_F9646', 'L-HISTIDINE_F4484', 'Glycochenodeoxycholic acid; LC-tDDA; CE20_F31633', 'N-ACETYLNEURAMINATE_F21231', 'HISTIDINE_F4826', 'ALPHA-AMINOADIPIC ACID_F7408', '3-AMINO-4-HYDROXYBENZOIC ACID_F4443', '4-Pyridoxic acid; AIF; CE10; CorrDec_F1660', 'Choline chloride_F4311', 'Phenylacetylglutamine_F16471', 'L-Proline_F6790', 'Allopurinol_F7163', 'Phenylacetylglutamine; AIF; CE30; CorrDec_F16062', 'Cysteinylglycine_F13139', 'trans-4-Hydroxy-L-proline_F11077', 'RAN-dm_F18082', 'Glutamine_F9178', '2-Naphthylamine_F946', 'Palmitoyl-carnitine; LC-tDDA; CE30_F28570', 'BETA-ALANINE_F1127', 'LysoPC(0:0/18:0)_F29348', '1-Stearoyl-sn-glycero-3-phosphocholine_F33424', 'Histidine_F4826', 'Oleoyl-carnitine; LC-tDDA; CE40_F25993', 'Creatine_F9524', '1-Acetylimidazole_F5136', 'GLYCOCHENODEOXYCHOLIC ACID_F31993', 'Linoleyl-carnitine; LC-tDDA; CE30_F24984', 'Proline_F6793', '2-HYDROXYPYRIDINE_F1670', '1-AMINOCYCLOPROPANECARBOXYLATE_F2471', 'Hypoxanthine_F12060', 'Linoleyl-carnitine; AIF; CE30; CorrDec_F30708', 'Phenylacetylglutamine_F13541', 'Oleoyl-carnitine; LC-tDDA; CE30_F25689', 'Cysteinylglycine_F13140', 'ADENOSINE_F17287', 'Glycodeoxycholic acid_F30942', 'INDOLE_F5446', 'Biliverdin_F38788', 'L-Proline_F6793', 'Omeprazole; AIF; CE10; MS2Dec_F21719', 'Oleoyl-carnitine; LC-tDDA; CE40_F31475', 'maltotriose_F25787', 'beta-Alanine; AIF; CE0; MS2Dec_F1112', 'Acetaminophen_F3583', 'PIPECOLIC ACID_F10803', 'Glycohyodeoxycholic acid_F23390', '2-Phenylacetamide_F1611', '2-Oxindole_F10090', 'Proline_F6791', 'gamma-Linolenic acid_F21587', 'Valeryl-carnitine; AIF; CE10; CorrDec_F9711', 'PC(16:0/18:1(9Z))_F38776', 'β-Gentiobiose_F23486', 'Sphingosine-1-Phosphate (d18:1)_F22748', '4-Pyridoxic acid; AIF; CE10; MS2Dec_F2085', '4-Pyridoxic acid;  ...
